# %% [markdown]
# # 📈 Professional Bitcoin Directional Prediction using XGBoost
# ## Optimized for hourly BTC/USDT analysis

# %%
# ==============================
# Imports
# ==============================
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import joblib
import warnings

from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from xgboost import XGBClassifier
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

warnings.filterwarnings('ignore')

# ==============================
# File Path (Local)
# ==============================
FILE_PATH = "../data/features/btc_features_complete.csv"

# ==============================
# Save Model & Scaler
# ==============================
MODEL_SAVE_PATH = "../models/xgboost/btc_xgboost_hourly_model.json"
SCALER_SAVE_PATH = "../models/xgboost/btc_xgboost_hourly_scaler.pkl"

# ==============================
# Styling (dark + crypto)
# ==============================
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (16, 9)

# 🎯 Crypto Palette
COLORS = ['#F7931A', '#00FF9C', '#FF4C4C']

# ==============================
# Data Loading
# ==============================
if not os.path.exists(FILE_PATH):
    raise FileNotFoundError(f"File {FILE_PATH} not found. Check the path.")

df = pd.read_csv(FILE_PATH)

print(df.head())
print(df.info())
print("Shape:", df.shape)
# Out:
#               Datetime      Open      High      Low     Close       Volume  \
# 0  2018-01-31 01:00:00   9829.99  10080.00  9700.00   9967.48  2341.104910
# 1  2018-01-31 02:00:00   9967.47  10278.00  9932.46  10229.84  1162.774900
# 2  2018-01-31 03:00:00  10229.77  10233.99  9967.00  10060.00   920.236009
# 3  2018-01-31 04:00:00  10069.96  10089.59  9888.00   9983.76   682.356001
# 4  2018-01-31 05:00:00   9985.00  10177.99  9810.00  10097.25  1008.606525
#
#     returns  log_returns  future_return_1h  future_return_6h  ...  nvt_ratio  \
# 0  0.013987     0.013890          0.026322          0.031354  ...   0.830917
# 1  0.026322     0.025981         -0.016602          0.000960  ...   0.830917
# 2 -0.016602    -0.016742         -0.007579          0.012971  ...   0.830917
# 3 -0.007579    -0.007607          0.011367          0.028116  ...   0.830917
# 4  0.011367     0.011303          0.014610          0.019094  ...   0.830917
#
#    fg_change_7d  extreme_fear  extreme_greed  sp500_returns  btc_sp500_corr  \
# 0           0.0             0              0            0.0        0.006809
# 1           0.0             0              0            0.0        0.006570
# 2           0.0             0              0            0.0        0.006692
# 3           0.0             0              0            0.0        0.006755
# 4           0.0             0              0            0.0        0.006770
#
#    dxy_returns  target_direction  target_class  target_regression
# 0          0.0                 1             4           0.026322
# 1          0.0                 0             0          -0.016602
# 2          0.0                 0             1          -0.007579
# 3          0.0                 1             4           0.011367
# 4          0.0                 1             4           0.014610
#
# [5 rows x 71 columns]
# <class 'pandas.DataFrame'>
# RangeIndex: 69861 entries, 0 to 69860
# Data columns (total 71 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Datetime            69861 non-null  str
#  1   Open                69861 non-null  float64
#  2   High                69861 non-null  float64
#  3   Low                 69861 non-null  float64
#  4   Close               69861 non-null  float64
#  5   Volume              69861 non-null  float64
#  6   returns             69861 non-null  float64
#  7   log_returns         69861 non-null  float64
#  8   future_return_1h    69861 non-null  float64
#  9   future_return_6h    69861 non-null  float64
#  10  future_return_24h   69861 non-null  float64
#  11  momentum_24h        69861 non-null  float64
#  12  momentum_7d         69861 non-null  float64
#  13  volatility_24h      69861 non-null  float64
#  14  volatility_7d       69861 non-null  float64
#  15  volume_ma_24h       69861 non-null  float64
#  16  volume_ratio        69861 non-null  float64
#  17  SMA_20              69861 non-null  float64
#  18  SMA_50              69861 non-null  float64
#  19  SMA_200             69861 non-null  float64
#  20  EMA_12              69861 non-null  float64
#  21  EMA_26              69861 non-null  float64
#  22  MACD                69861 non-null  float64
#  23  MACD_signal         69861 non-null  float64
#  24  MACD_hist           69861 non-null  float64
#  25  RSI_14              69861 non-null  float64
#  26  RSI_21              69861 non-null  float64
#  27  STOCH_K             69861 non-null  float64
#  28  STOCH_D             69861 non-null  float64
#  29  ATR_14              69861 non-null  float64
#  30  BB_upper            69861 non-null  float64
#  31  BB_middle           69861 non-null  float64
#  32  BB_lower            69861 non-null  float64
#  33  ADX_14              69861 non-null  float64
#  34  CCI_20              69861 non-null  float64
#  35  WILLR_14            69861 non-null  float64
#  36  MFI_14              69861 non-null  float64
#  37  OBV                 69861 non-null  float64
#  38  close_to_sma20      69861 non-null  float64
#  39  close_to_sma50      69861 non-null  float64
#  40  close_to_sma200     69861 non-null  float64
#  41  market_price_usd    69861 non-null  float64
#  42  hash_rate_th_s      69861 non-null  float64
#  43  difficulty          69861 non-null  float64
#  44  tx_count_daily      69861 non-null  float64
#  45  tx_fees_btc         69861 non-null  float64
#  46  avg_block_size_mb   69861 non-null  float64
#  47  mempool_size_bytes  69861 non-null  float64
#  48  total_btc_supply    69861 non-null  float64
#  49  sp500               69861 non-null  float64
#  50  nasdaq              69861 non-null  float64
#  51  dxy                 69861 non-null  float64
#  52  gold                69861 non-null  float64
#  53  oil                 69861 non-null  float64
#  54  eur_usd             69861 non-null  float64
#  55  gbp_usd             69861 non-null  float64
#  56  jpy_usd             69861 non-null  float64
#  57  fear_greed_value    69861 non-null  float64
#  58  fear_greed_label    69861 non-null  str
#  59  hash_rate_pct_7d    69861 non-null  float64
#  60  difficulty_pct_7d   69861 non-null  float64
#  61  nvt_ratio           69861 non-null  float64
#  62  fg_change_7d        69861 non-null  float64
#  63  extreme_fear        69861 non-null  int64
#  64  extreme_greed       69861 non-null  int64
#  65  sp500_returns       69861 non-null  float64
#  66  btc_sp500_corr      69861 non-null  float64
#  67  dxy_returns         69861 non-null  float64
#  68  target_direction    69861 non-null  int64
#  69  target_class        69861 non-null  int64
#  70  target_regression   69861 non-null  float64
# dtypes: float64(65), int64(4), str(2)
# memory usage: 37.8 MB
# None
# Shape: (69861, 71)

# %% [markdown]
# ---
# ## 1. Data Ingestion & Sequence Engineering
# We use the comprehensive dataset generated by our production pipeline, focusing on numeric inputs and adding behavioral lags.

# %%
def load_and_preprocess(path):
    df = pd.read_csv(path, index_col=0, parse_dates=True)

    # Professional Rule: Automaticaly select only numeric columns for model inputs
    df = df.select_dtypes(include=[np.number])

    print(f"Initial numeric dataset shape: {df.shape}")

    # Engineering lags for the top technical indicators
    target_lags = ['returns', 'RSI_14', 'MACDHIST', 'Close', 'Volume']
    existing_lags = [f for f in target_lags if f in df.columns]

    for f in existing_lags:
        for lag in range(1, 6):
            df[f"{f}_lag_{lag}"] = df[f].shift(lag)

    return df.ffill().bfill().dropna()

df = load_and_preprocess(FILE_PATH)
print(f"Processing complete. Total features (with lags): {len(df.columns)}")
# Out:
# Initial numeric dataset shape: (69861, 69)
# Processing complete. Total features (with lags): 89

# %% [markdown]
# ---
# ## 2. Advanced Feature Selection
# Selecting variables that have the highest ANOVA F-value relative to the direction and filtering out highly correlated features to minimize redundancy.

# %%
def select_features(df, k=25):
    target = 'target_direction'
    # Ensure target exists
    if target not in df.columns:
        # Create target if missing (1 if returns > 0 else 0)
        df[target] = np.where(df['returns'].shift(-1) > 0, 1, 0)
        df = df.dropna()

    X_raw = df.drop([c for c in df.columns if 'target' in c.lower() or 'future_return' in c.lower()], axis=1)
    y = df[target]

    # Univariate selection
    selector = SelectKBest(score_func=f_classif, k=min(k*2, X_raw.shape[1]))
    selector.fit(X_raw, y)
    top_raw_cols = X_raw.columns[selector.get_support()]

    # Multicollinearity Filter
    corr_matrix = X_raw[top_raw_cols].corr().abs()
    upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

    final_cols = [c for c in top_raw_cols if c not in to_drop][:k]

    # Visualization
    scores = pd.Series(selector.scores_, index=X_raw.columns).loc[final_cols].sort_values(ascending=False).head(15)
    scores.plot(kind='barh', color=COLORS[0])
    plt.title('Top 15 Filtered Predictive Indicators (F-Scores)')
    plt.show()

    return final_cols

top_features = select_features(df, k=25)
print(f"Selected Top 25 features: {top_features[:5]}...")
# Out:
# Selected Top 25 features: ['Open', 'returns', 'momentum_24h', 'MACD', 'MACD_hist']...

# %% [markdown]
# ---
# ## 3. XGBoost Model Training
# Preparing the data and optimizing for regularization strength.

# %%
# Prepare arrays
X = df[top_features]
y = df['target_direction']

# 80% split (sequential)
cutoff = int(len(X) * 0.8)
X_train, X_test = X.iloc[:cutoff], X.iloc[cutoff:]
y_train, y_test = y.iloc[:cutoff], y.iloc[cutoff:]

# Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print(f"Training set: {len(X_train)} | Test set: {len(X_test)}")
# Out:
# Training set: 55888 | Test set: 13973

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [3, 5, 7],
    "learning_rate": [0.01, 0.1, 0.2]
}

tscv = TimeSeriesSplit(n_splits=5)

print("🔍 Optimizing XGBoost hyperparameters...")
grid_search = GridSearchCV(
    XGBClassifier(eval_metric="logloss"),
    param_grid,
    cv=tscv,
    scoring='accuracy',
    n_jobs=-1
)
grid_search.fit(X_train_scaled, y_train)

best_xgb = grid_search.best_estimator_
print(f"✅ Best Parameters Found: {grid_search.best_params_}")
# Out:
# 🔍 Optimizing XGBoost hyperparameters...
# ✅ Best Parameters Found: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 300}

# %% [markdown]
# ---
# ## 4. Evaluation & Backtesting
# Comparing predictive accuracy and financial outcomes.

# %%
y_pred = best_xgb.predict(X_test_scaled)
acc = accuracy_score(y_test, y_pred)

print(f"📈 Final Accuracy Score: {acc:.2%}")
print("\n--- Classification Report ---")
print(classification_report(y_test, y_pred))
# Out:
# 📈 Final Accuracy Score: 53.17%
#
# --- Classification Report ---
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51      6900
#            1       0.54      0.56      0.55      7073
#
#     accuracy                           0.53     13973
#    macro avg       0.53      0.53      0.53     13973
# weighted avg       0.53      0.53      0.53     13973

# %%
def calculate_metrics(returns):
    sharpe = (returns.mean() / returns.std()) * np.sqrt(24 * 365) if returns.std() != 0 else 0
    cum_ret = (1 + returns).cumprod()
    drawdown = cum_ret / cum_ret.cummax() - 1
    max_dd = drawdown.min()
    vol = returns.std() * np.sqrt(24 * 365)
    return sharpe, max_dd, vol, cum_ret.iloc[-1] - 1

def run_professional_backtest(y_test, y_pred, df_full):
    test_period = df_full.iloc[-len(y_test):].copy()

    test_period['signal'] = np.where(y_pred == 1, 1, -1)
    test_period['strat_ret'] = test_period['signal'].shift(1) * test_period['returns']
    test_period = test_period.dropna()

    s_sharpe, s_mdd, s_vol, s_ret = calculate_metrics(test_period['strat_ret'])
    b_sharpe, b_mdd, b_vol, b_ret = calculate_metrics(test_period['returns'])

    fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, gridspec_kw={'height_ratios': [3, 1]})

    ((1 + test_period['returns']).cumprod()).plot(ax=ax1, label=f'Benchmark (Return: {b_ret:.1%})', color='gray', alpha=0.5)
    ((1 + test_period['strat_ret']).cumprod()).plot(ax=ax1, label=f'LR Strategy (Return: {s_ret:.1%})', color=COLORS[2], linewidth=2)
    ax1.set_title(f'XGBoost Performance (Sharpe: {s_sharpe:.2f})', fontsize=18)
    ax1.legend(loc='upper left')
    ax1.set_ylabel('Cumulative Growth (x)')

    dd = (1 + test_period['strat_ret']).cumprod() / (1 + test_period['strat_ret']).cumprod().cummax() - 1
    ax2.fill_between(dd.index, dd, 0, color=COLORS[1], alpha=0.3)
    ax2.set_ylabel('Drawdown %')
    ax2.set_ylim(-0.35, 0.05)

    plt.tight_layout()
    plt.show()

    stats = pd.DataFrame({
        'Metric': ['Total Return', 'Ann. Volatility', 'Sharpe Ratio', 'Max Drawdown'],
        'Strategy': [f"{s_ret:.1%}", f"{s_vol:.1%}", f"{s_sharpe:.2f}", f"{s_mdd:.1%}"],
        'Benchmark': [f"{b_ret:.1%}", f"{b_vol:.1%}", f"{b_sharpe:.2f}", f"{b_mdd:.1%}"]
    })
    print("\n--- Strategy Performance Comparison ---")
    print(stats.to_string(index=False))

run_professional_backtest(y_test, y_pred, df)
# Out:
# --- Strategy Performance Comparison ---
#          Metric Strategy Benchmark
#    Total Return   273.5%     39.4%
# Ann. Volatility    46.9%     46.9%
#    Sharpe Ratio     2.00      0.68
#    Max Drawdown   -25.5%    -34.8%

# %% [markdown]
# ---
# ## 5. Persistence
# Saving results for inference.

# %%
os.makedirs('../models/xgboost', exist_ok=True)
best_xgb.save_model(MODEL_SAVE_PATH)
joblib.dump(scaler, SCALER_SAVE_PATH)
print(f"✅ Successfully exported model to {MODEL_SAVE_PATH}")
# Out:
# ✅ Successfully exported model to ../models/xgboost/btc_xgboost_hourly_model.json

# %%
import json
import datetime

# Prepare metadata
metadata = {
    "model_name": "XGBoost BTC",
    "accuracy": acc,
    "best_params": grid_search.best_params_,
    "top_features": top_features,
    "training_size": len(X_train),
    "test_size": len(X_test),
    "export_timestamp": datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
}

# Save to JSON
METADATA_SAVE_PATH = "../models/xgboost/btc_xgboost_hourly_metadata.json"
with open(METADATA_SAVE_PATH, 'w') as f:
    json.dump(metadata, f, indent=4)

print(f"✅ Successfully exported model metadata to {METADATA_SAVE_PATH}")
print(json.dumps(metadata, indent=4))
# Out:
# ✅ Successfully exported model metadata to ../models/xgboost/btc_xgboost_hourly_metadata.json
# {
#     "model_name": "XGBoost BTC",
#     "accuracy": 0.53173978386889,
#     "best_params": {
#         "learning_rate": 0.01,
#         "max_depth": 3,
#         "n_estimators": 300
#     },
#     "top_features": [
#         "Open",
#         "returns",
#         "momentum_24h",
#         "MACD",
#         "MACD_hist",
#         "RSI_14",
#         "STOCH_K",
#         "STOCH_D",
#         "ADX_14",
#         "CCI_20",
#         "WILLR_14",
#         "MFI_14",
#         "OBV",
#         "close_to_sma20",
#         "close_to_sma50",
#         "close_to_sma200",
#         "mempool_size_bytes",
#         "dxy",
#         "oil",
#         "fear_greed_value",
#         "nvt_ratio",
#         "returns_lag_1",
#         "returns_lag_2",
#         "returns_lag_3",
#         "returns_lag_4"
#     ],
#     "training_size": 55888,
#     "test_size": 13973,
#     "export_timestamp": "2026-02-04 22:22:05"
# }
